# %%
import importlib
import experiment
importlib.reload(experiment)
import models
importlib.reload(models)

from experiment import *

# %%
exp_name = "GST-D1-HLM"

from pathlib import Path
path = Path("./data/GST-DCP1-HLM+E3-LSM-221219/gst-D1-HLM_VS_E3-LSM")
fs = sorted(list(path.glob("*.csv")))

controls_path = Path("./data/GST-DCP1-HLM+E3-LSM-221219/controls")
controls_fs = sorted(list(controls_path.glob("*.csv")))
print(len(fs))
print(len(controls_fs))
# Out:
# 17
# 5

# %%
exp = Exp()
exp.load_bli_data(fs)
exp.plot()

#remove loading and baselines
for ds in exp:
    s = ds.steps[0].start
    mask = ds.t >= s
    ds.response = ds.response[mask]
    ds.t = ds.t[mask]
# Out:
# Exp.params is None. Fit and offset plots are not available

# %%
controls = Exp()
controls.load_bli_data(controls_fs)
controls.interstep_correction()
controls.plot()
# Out:
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
#load descriptions, need to copy from blitz
desc = Path("./data/GST-DCP1-HLM+E3-LSM-221219/dataset_description.txt")
df = pd.read_csv(desc, sep='\t', index_col=0)
df
# Out:
#        Show  Analyze  Ref. Sample ID  Conc. (uM)  Run time (s)  \
# Index
# 1         1        0     0     blank         0.0           420
# 2         1        0     0    blank2         NaN           420
# 3         1        0     0    blank3         NaN           420
# 4         1        0     0       NaN        24.0           420
# 5         1        0     0    blank4         NaN           420
# 6         1        1     0       NaN        16.0           420
# 7         1        1     0       NaN         8.0           420
# 8         1        1     0       NaN         4.0           420
# 9         1        0     0       NaN         2.0           420
# 10        1        1     0       NaN         1.0           420
# 11        1        1     0       NaN         1.0           420
# 12        1        1     0       NaN         2.0           420
# 13        1        1     0       NaN         4.0           420
# 14        1        1     0       NaN         8.0           420
# 15        1        0     0       NaN        16.0           420
# 16        1        1     0       NaN         2.0           420
# 17        1        1     0       NaN        16.0           420
#
#        Shaker speed (rpm)  Integration (ms) Biosensor Type  \
# Index
# 1                    1000               2.3       Anti-GST
# 2                    1000               2.3       Anti-GST
# 3                    1000               2.3       Anti-GST
# 4                    1000               2.3       Anti-GST
# 5                    1000               2.2       Anti-GST
# 6                    1000               2.2       Anti-GST
# 7                    1000               2.2       Anti-GST
# 8                    1000               2.2       Anti-GST
# 9                    1000               2.3       Anti-GST
# 10                   1000               2.4       Anti-GST
# 11                   1000               2.3       Anti-GST
# 12                   1000               2.4       Anti-GST
# 13                   1000               2.2       Anti-GST
# 14                   1000               2.2       Anti-GST
# 15                   1000               1.9       Anti-GST
# 16                   1000               2.1       Anti-GST
# 17                   1000               2.1       Anti-GST
#
#                             Information              Status
# Index
# 1                  calkiem pusty sensor                 NaN
# 2                     no bait, 24uM LSM                 NaN
# 3                  bait + blank analyte                 NaN
# 4              sensor ten co poprzednio                 NaN
# 5      no bait, 24uM LSM, czysty sensor                 NaN
# 6                                   NaN                 NaN
# 7                                   NaN                 NaN
# 8                                   NaN                 NaN
# 9      dysocjacja poszla w pustej tubce  Saturated response
# 10                 nisko sie zaladowalo                 NaN
# 11                                  NaN                 NaN
# 12                                  NaN                 NaN
# 13                                  NaN                 NaN
# 14                                  NaN                 NaN
# 15                                  NaN                 NaN
# 16                                  NaN                 NaN
# 17                                  NaN                 NaN

# %%
#assign concentrations from desc to each dataset
concs = df['Conc. (uM)'].to_dict()
analyze = df['Analyze'].to_dict()

for ds in exp.datasets:
    idx = ds.name[:-4].split('_')[-1]
    idx=int(idx)
    c = concs[idx]
    if np.isnan(c): c=0
    ds.steps[0].concentration = c*1e-6
    ds.use_for_fit = analyze[idx]

# %%
#assign conentrations to controls
controls_c = [1,2,4,8,16]
controls_c = [c*1e-6 for c in controls_c]

for ds, c in zip(controls, controls_c):
    ds.steps[0].concentration = c

# %%
controls_dict = {}
for ds in controls:
    control_mask = ds.t>=ds.steps[0].start
    c = ds.steps[0].concentration
    controls_dict[c] = ds.response[control_mask]


#subtract controls from ds
for ds in exp:
    if not ds.use_for_fit: continue
    print(ds.steps[0].concentration)
    start = ds.steps[0].start
    mask = ds.t>=start
    r = ds.response[mask]
    c = ds.steps[0].concentration
    if c in controls_dict:
        print('correcting c=',c)
        #analyte ref
        ds.response[mask] = np.subtract(r, controls_dict[c])
        #lig ref
        ds.response[mask] = np.subtract(ds.response[mask], exp.datasets[2].response[mask])
    
        
exp.interstep_correction()
exp.plot()
# Out:
# 1.6e-05
# correcting c= 1.6e-05
# 8e-06
# correcting c= 8e-06
# 4e-06
# correcting c= 4e-06
# 1e-06
# correcting c= 1e-06
# 1e-06
# correcting c= 1e-06
# 2e-06
# correcting c= 2e-06
# 4e-06
# correcting c= 4e-06
# 8e-06
# correcting c= 8e-06
# 2e-06
# correcting c= 2e-06
# 1.6e-05
# correcting c= 1.6e-05
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
# exp.crop(5)

# %%
for ds in exp:
    print(ds.index, ds.name)
# Out:
# 0 2022-12-20_001.csv
# 1 2022-12-20_002.csv
# 2 2022-12-20_003.csv
# 3 2022-12-20_004.csv
# 4 2022-12-20_005.csv
# 5 2022-12-20_006.csv
# 6 2022-12-20_007.csv
# 7 2022-12-20_008.csv
# 8 2022-12-20_009.csv
# 9 2022-12-20_010.csv
# 10 2022-12-20_011.csv
# 11 2022-12-20_012.csv
# 12 2022-12-20_013.csv
# 13 2022-12-20_014.csv
# 14 2022-12-20_015.csv
# 15 2022-12-20_016.csv
# 16 2022-12-20_017.csv

# %%
#remove some datasets
ds_to_remove = []
for ds in exp:
    if ds.use_for_fit == False:
        ds_to_remove.append(ds)
    if ds.index in []:
        ds_to_remove.append(ds)
for ds in ds_to_remove:
    exp.datasets.remove(ds)

# %%
exp.model = models.One_to_one()
exp.model.params_definitions
# Out:
# {'ka': <Parameter 'ka', value=10000.0, bounds=[10.0:10000000.0]>,
#  'kd': <Parameter 'kd', value=0.01, bounds=[1e-06:0.1]>,
#  'kt': <Parameter 'kt', value=10000000.0, bounds=[10.0:1000000000000.0]>,
#  'ymax': <Parameter 'ymax', value=1, bounds=[1e-12:1000]>,
#  'offset': <Parameter 'offset', value=0, bounds=[-1000:1000]>}

# %%
# exp.model.params_definitions['ymax'].user_data['type']='global'

exp.model.params_definitions['offset'].min= -0.1
exp.model.params_definitions['offset'].max= 0.1
exp.model.params_definitions['ymax'].max= 1
exp.model.params_definitions['ymax'].value= 0.25
exp.model.params_definitions['ka'].max= 1e5
exp.model.params_definitions['ka'].min= 100
exp.model.params_definitions['ka'].value = 5000

# exp.model.params_definitions['offset'].min= -0.1
# exp.model.params_definitions['offset'].max= 0.1
# exp.model.params_definitions['ymax1'].max= 1
# exp.model.params_definitions['ymax2'].max= 1

exp.create_params(offsets=True, mtl = False)

# %%
exp.fit_params()
# Out:
# fitting using: least_squares
# '`ftol` termination condition is satisfied.'

# %%
exp.plot(fit=True, correct_offsets=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
from uncertainties import ufloat
ka = exp.result.params['ka'].value
ka_err = exp.result.params['ka'].stderr
kaa = ufloat(ka, ka_err)

kd = exp.result.params['kd'].value
kd_err = exp.result.params['kd'].stderr
kdd = ufloat(kd, kd_err)

Kd = kdd/kaa
Kd
# Out:
# 8.278470816948663e-06+/-1.439056538205451e-07

# %%
exp.summary()
# Out:
# 'ka: 4.6786E+03\nkd: 3.8732E-02\nKD:8.2785E-06\nR²: 0.9834\nchi²: 0.8767090640901545\nreduced chi²: 7.325443383106237e-05\n'

# %%
import plotly.graph_objects as go

fig = go.Figure()

for ds in exp.datasets:
    if ds.use_for_fit == False: continue
    x = np.array([])
    y = np.array([])
    y_fit = np.array([])
    
    for step in ds.steps:
        # if step.concentration>0: color = 'orangered'
        # elif step.concentration==0: color = 'cornflowerBlue'
        # else: color = 'lightgrey'
        mask = (ds.t>=step.start) & (ds.t<step.stop)

        if f"offset_ds{ds.index}_step{step.index}" in exp.params:
                offset = exp.params[f'offset_ds{ds.index}_step{step.index}'].value
        else: 
            offset = 0
        
        x_step = ds.t[mask]
        y_step = ds.response[mask] - offset
        y_fit_step = ds.fit_response[mask] - offset

        x = np.concatenate([x, x_step])
        y = np.concatenate([y, y_step])
        y_fit = np.concatenate([y_fit, y_fit_step])

    
    x = x - x[0]
    fig.add_scatter(x = x, 
                    y = y_fit,
                    marker=dict(size=0, 
                            color='black',
                            line=dict(width=1, color='black')),
                    line=dict(
                         width=2, 
                         color='black'
                         ),
                    name=ds.steps[0].concentration,)

        

    fig.add_scatter(x = x,
                    y = y,
                    marker=dict(
                            size=0, 
                            #color=color, 
                            line=dict(
                                    width=0.1, 
                                    #color=color
                                    )),
                    line=dict(
                            width=1, 
                            #color=color
                            ),
                    name=f"{ds.index}_{ds.steps[0].concentration}",
                    )



fig.update_layout(
            height=600,
            width = 800,
            font_family="Arial",
            font_size = 24,
            showlegend=False,
            margin=dict(l=0,r=0,b=0,t=0,pad=0), 
            template='plotly_white',
            paper_bgcolor="rgb(255, 255, 255)",  
            plot_bgcolor="rgb(255, 255, 255)") 

fig.update_xaxes(
    ticklabelposition="inside top", 
    title='time [s]',
    showline=True, 
    linewidth=1, 
    linecolor='black', 
    showgrid=False,
    mirror=True)

fig.update_yaxes(
    ticklabelposition="outside top", 
    title='Response [nm]',
    showline=True, 
    linewidth=1, 
    linecolor='black', 
    showgrid=False,
    mirror=True)



fig.show()

# %%
for ds in exp:
    if ds.index in [9, 15,  6, 12, 5]:#, 15, 6, 7, 16, 5]:
        ds.use_for_fit = False
    if ds.index in []:
        ds.use_for_fit = True
    # if ds.steps[0].concentration==16e-6:
    #     ds.use_for_fit = True

# %%
for ds in exp:
    ds.use_for_fit = True

# %%
exp.crop(3)

# %%
# exp.result

# %%
r = exp.result
r.residual.shape
1 - r.residual.var() / np.var(y)
# Out:
# nan

# %%
plt.plot(exp.result.residual)

# %%
import kaleido
exp_name = "GST-D1_E3-HLM"
fig.write_image(f'{exp_name}-{exp.model.name}.png')

# %%
report_filename = 'gst-d1-hlm_e3-lsm'

from lmfit.printfuncs import fitreport_html_table
s = fitreport_html_table(exp.result, show_correl=True,  min_correl=0.1)

with open(f"{exp_name}.htm", 'w') as f:
    f.write(s)

# %%
from uncertainties import ufloat
def get_html_report(show_correl=True):
    result = exp.result
    tables = result._repr_html_(show_correl=show_correl)
    
    if ('ka' in result.params) and ('kd' in result.params):
        t = []
        cell = lambda x, tag: f'<{tag}> {x} </{tag}>'
        
        has_er = hasattr(result.params['ka'], 'stderr') and (result.params['ka'].stderr is not None)

        if has_er:
            ka = ufloat(float(result.params['ka'].value), float(result.params['ka'].stderr))
            kd = ufloat(float(result.params['kd'].value), float(result.params['kd'].stderr))
            Kd = kd/ka
        else:
            Kd = result.params['kd'].value/result.params['ka'].value

        t.append('<h2>Dissociation constant</h2>')
        t.append('<table><tr>')
        t.append(cell(f"<b>Name</b>", 'td'))
        t.append(cell(f"<b>value</b>", 'td'))
        t.append(cell(f"<b>standard error</b>", 'td'))
        t.append(cell(f"<b>relative error</b>", 'td'))  
        t.append('</tr><tr>')
        t.append(cell(f"<b>Kd</b>", 'td'))
        if has_er:
            t.append(cell(f"{Kd.n:.5e}", 'td'))
            t.append(cell(f"{Kd.std_dev:.5e}", 'td'))
            t.append(cell(f"{Kd.std_dev/Kd.n:.2%}", 'td'))
        else:
            t.append(cell(f"{Kd:.5e}", 'td'))
            t.append(cell("NA", 'td'))
            t.append(cell("NA", 'td'))
        t.append('</table></tr></table>')

        return tables + ''.join(t)
    
    else: 
        return tables

report = get_html_report(show_correl=False)
with open(f'{exp_name}extended_report.htm','w') as f:
    f.write(report)

# %%
params = exp.result.params
y0=None
resids = []
y_data = []

for dataset in exp:
    if dataset.use_for_fit == False: 
        continue
    dataset_resids = dataset.response - exp.calc_dataset_response_from_params(dataset, params, y0)
    resids.append(dataset_resids)
    y_data.append(dataset.response)

residuals = np.concatenate(resids)
y_data = np.concatenate(y_data)
residuals.shape
y_data.shape
# Out:
# (6000,)

# %%
residuals = exp.result.residual
mask = ~np.isnan(y_data)
y_data = y_data[mask]

ss_res = np.sum(residuals**2)
ss_tot = np.sum((y_data-np.mean(y_data))**2)

# %%
r_squared = 1 - (ss_res / ss_tot)
r_squared
# Out:
# 0.982435853992191

# %%
1 - exp.result.residual.var() / np.var(y_data)
# Out:
# 0.9912179269960956

# %%
params = exp.result.params
y0=None
resids = []
y_data = []

for dataset in exp:
    if dataset.use_for_fit == False: 
        continue
    dataset_resids = dataset.response - exp.calc_dataset_response_from_params(dataset, params, y0)
    resids.append(dataset_resids)
    y_data.append(dataset.response)

residuals = np.concatenate(resids)
y_data = np.concatenate(y_data)
residuals.shape
y_data.shape
# Out:
# (6000,)

# %%
1 - exp.result.redchi / np.var(y, ddof=2)
# Out:
# 0.9946477223963922

# %%
resi = exp.result.residual
exp.result.residual.var()
# Out:
# 0.3903185760434541

# %%
1 - (exp.result.residual.var() / np.var(y))
# Out:
# -0.04384678738694392

# %%
rss = (resi**2).sum()
rss
# Out:
# 11508.154249688201

# %%
tss = sum(np.power(resi - np.mean(resi), 2)) 
print(f"TSS = {tss:.1f}")

print(f"R² = {1 - rss/tss:.3f}")
# Out:
# TSS = 8001.5
# R² = -0.438

# %%
y2.shape
# Out:
# (20500,)

# %%
exp.result.residual.shape
# Out:
# (12000,)

# %%
0.07461523/248.991774
# Out:
# 0.00029966945815647713

# %%
0.01498096/37982.4598
# Out:
# 3.944178465239895e-07

# %%
exp.result
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>least_squares</td><td></td></tr><tr><td># function evals</td><td>6996</td><td></td></tr><tr><td># data points</td><td>12000</td><td></td></tr><tr><td># variables</td><td>44</td><td></td></tr><tr><td>chi-square</td><td> 0.40604874</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.3962e-05</td><td></td></tr><tr><td>Akaike info crit.</td><td>-123439.328</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-123114.051</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> ka1 </td><td>  248.991774 </td><td>  91.3099345 </td><td> (36.67%) </td><td> 10000.0 </td><td>  10.0000000 </td><td>  10000000.0 </td><td> True </td></tr><tr><td> kd1 </td><td>  0.07461523 </td><td>  8.4185e-04 </td><td> (1.13%) </td><td> 0.01 </td><td>  1.0000e-06 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> ka2 </td><td>  37982.4598 </td><td>  1312.90197 </td><td> (3.46%) </td><td> 10000.0 </td><td>  10.0000000 </td><td>  10000000.0 </td><td> True </td></tr><tr><td> kd2 </td><td>  0.01498096 </td><td>  5.0325e-04 </td><td> (3.36%) </td><td> 0.01 </td><td>  1.0000e-06 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> ymax1_ds5 </td><td>  3.71657546 </td><td>  1.30773224 </td><td> (35.19%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds6 </td><td>  3.03684881 </td><td>  1.08816739 </td><td> (35.83%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds7 </td><td>  6.45213345 </td><td>  2.36985114 </td><td> (36.73%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds9 </td><td> 10.00000000 </td><td>  3.75287012 </td><td> (37.53%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds10 </td><td>  9.47709596 </td><td>  3.53021228 </td><td> (37.25%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds11 </td><td>  6.86466937 </td><td>  2.50918626 </td><td> (36.55%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds12 </td><td>  6.59729368 </td><td>  2.40919201 </td><td> (36.52%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds13 </td><td>  3.86310520 </td><td>  1.39512861 </td><td> (36.11%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds15 </td><td>  9.67200764 </td><td>  3.58473832 </td><td> (37.06%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax1_ds16 </td><td>  3.14898554 </td><td>  1.10819117 </td><td> (35.19%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds5 </td><td>  0.03775272 </td><td>  0.00208270 </td><td> (5.52%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds6 </td><td>  0.10854252 </td><td>  0.00169642 </td><td> (1.56%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds7 </td><td>  0.04955274 </td><td>  0.00196526 </td><td> (3.97%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds9 </td><td>  1.0000e-12 </td><td>  0.00251112 </td><td> (251111741063.95%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds10 </td><td>  0.04701649 </td><td>  0.00268738 </td><td> (5.72%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds11 </td><td>  0.07688215 </td><td>  0.00251812 </td><td> (3.28%) </td><td> 1 </td><td>  1.0000e-12 </td><td>  10.0000000 </td><td> True </td></tr><tr><td> ymax2_ds12 </td><td>  0.08131497  ...
