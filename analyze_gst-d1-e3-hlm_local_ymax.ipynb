# %%
import importlib
import experiment
importlib.reload(experiment)
import models
importlib.reload(models)

from experiment import *

# %%
exp_name = "GST-D1-HLM"

from pathlib import Path
path = Path("./data/GST-DCP1-HLM+E3-LSM-221219/gst-D1-HLM_VS_E3-LSM")
fs = sorted(list(path.glob("*.csv")))

controls_path = Path("./data/GST-DCP1-HLM+E3-LSM-221219/controls")
controls_fs = sorted(list(controls_path.glob("*.csv")))
print(len(fs))
print(len(controls_fs))
# Out:
# 17
# 5

# %%
exp = Exp()
exp.load_bli_data(fs)
exp.plot()
# Out:
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
controls = Exp()
controls.load_bli_data(controls_fs)
controls.interstep_correction()
controls.plot()
# Out:
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
#load descriptions, need to copy from blitz
desc = Path("./data/GST-DCP1-HLM+E3-LSM-221219/dataset_description.txt")
df = pd.read_csv(desc, sep='\t', index_col=0)
df
# Out:
#        Show  Analyze  Ref. Sample ID  Conc. (uM)  Run time (s)  \
# Index
# 1         1        0     0     blank         0.0           420
# 2         1        0     0    blank2         NaN           420
# 3         1        0     0    blank3         NaN           420
# 4         1        0     0       NaN        24.0           420
# 5         1        0     0    blank4         NaN           420
# 6         1        1     0       NaN        16.0           420
# 7         1        1     0       NaN         8.0           420
# 8         1        1     0       NaN         4.0           420
# 9         1        0     0       NaN         2.0           420
# 10        1        1     0       NaN         1.0           420
# 11        1        1     0       NaN         1.0           420
# 12        1        1     0       NaN         2.0           420
# 13        1        1     0       NaN         4.0           420
# 14        1        1     0       NaN         8.0           420
# 15        1        0     0       NaN        16.0           420
# 16        1        1     0       NaN         2.0           420
# 17        1        1     0       NaN        16.0           420
#
#        Shaker speed (rpm)  Integration (ms) Biosensor Type  \
# Index
# 1                    1000               2.3       Anti-GST
# 2                    1000               2.3       Anti-GST
# 3                    1000               2.3       Anti-GST
# 4                    1000               2.3       Anti-GST
# 5                    1000               2.2       Anti-GST
# 6                    1000               2.2       Anti-GST
# 7                    1000               2.2       Anti-GST
# 8                    1000               2.2       Anti-GST
# 9                    1000               2.3       Anti-GST
# 10                   1000               2.4       Anti-GST
# 11                   1000               2.3       Anti-GST
# 12                   1000               2.4       Anti-GST
# 13                   1000               2.2       Anti-GST
# 14                   1000               2.2       Anti-GST
# 15                   1000               1.9       Anti-GST
# 16                   1000               2.1       Anti-GST
# 17                   1000               2.1       Anti-GST
#
#                             Information              Status
# Index
# 1                  calkiem pusty sensor                 NaN
# 2                     no bait, 24uM LSM                 NaN
# 3                  bait + blank analyte                 NaN
# 4              sensor ten co poprzednio                 NaN
# 5      no bait, 24uM LSM, czysty sensor                 NaN
# 6                                   NaN                 NaN
# 7                                   NaN                 NaN
# 8                                   NaN                 NaN
# 9      dysocjacja poszla w pustej tubce  Saturated response
# 10                 nisko sie zaladowalo                 NaN
# 11                                  NaN                 NaN
# 12                                  NaN                 NaN
# 13                                  NaN                 NaN
# 14                                  NaN                 NaN
# 15                                  NaN                 NaN
# 16                                  NaN                 NaN
# 17                                  NaN                 NaN

# %%
#assign concentrations from desc to each dataset
concs = df['Conc. (uM)'].to_dict()
analyze = df['Analyze'].to_dict()

for ds in exp.datasets:
    idx = ds.name[:-4].split('_')[-1]
    idx=int(idx)
    c = concs[idx]
    if np.isnan(c): c=0
    ds.steps[0].concentration = c*1e-6
    ds.use_for_fit = analyze[idx]

# %%
for ds in exp.datasets:
    print(ds)
exp.interstep_correction()
exp.plot()
# Out:
# Dataset(0, name = 2022-12-20_001.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(1, name = 2022-12-20_002.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(2, name = 2022-12-20_003.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(3, name = 2022-12-20_004.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(4, name = 2022-12-20_005.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(5, name = 2022-12-20_006.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(6, name = 2022-12-20_007.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(7, name = 2022-12-20_008.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(8, name = 2022-12-20_009.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(9, name = 2022-12-20_010.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(10, name = 2022-12-20_011.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(11, name = 2022-12-20_012.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(12, name = 2022-12-20_013.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(13, name = 2022-12-20_014.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(14, name = 2022-12-20_015.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)
# Dataset(15, name = 2022-12-20_016.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Dataset(16, name = 2022-12-20_017.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
#assign conentrations to controls
controls_c = [1,2,4,8,16]
controls_c = [c*1e-6 for c in controls_c]

for ds, c in zip(controls, controls_c):
    ds.steps[0].concentration = c

# %%
exp
# Out:
# <Exp>: Model = <NA> (NA params), Datasets = 17, fitted = No
# 	<Dataset(0, name = 2022-12-20_001.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 0.0, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(1, name = 2022-12-20_002.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 0.0, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(2, name = 2022-12-20_003.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 0.0, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(3, name = 2022-12-20_004.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 2.4e-05, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(4, name = 2022-12-20_005.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 0.0, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(5, name = 2022-12-20_006.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 1.6e-05, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(6, name = 2022-12-20_007.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 8e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(7, name = 2022-12-20_008.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 4e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(8, name = 2022-12-20_009.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 2e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(9, name = 2022-12-20_010.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 1e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(10, name = 2022-12-20_011.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 1e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(11, name = 2022-12-20_012.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 2e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(12, name = 2022-12-20_013.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 4e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(13, name = 2022-12-20_014.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 8e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(14, name = 2022-12-20_015.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 0)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 1.6e-05, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(15, name = 2022-12-20_016.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 2e-06, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>
# 	<Dataset(16, name = 2022-12-20_017.csv, no_steps = 2, len = 419.8, baseline = (150.0, 180.0), use_for_fit = 1)>
# 		<Step(0, start = 180.0, stop = 300.0, len = 120.0, c = 1.6e-05, type = Association)>
# 		<Step(1, start = 300.0, stop = 420, len = 120.0, c = 0, type = Dissociation)>

# %%
controls_dict = {}
for ds in controls:
    control_mask = ds.t>=ds.steps[0].start
    c = ds.steps[0].concentration
    controls_dict[c] = ds.response[control_mask]


#subtract controls from ds
for ds in exp:
    if not ds.use_for_fit: continue
    print(ds.steps[0].concentration)
    start = ds.steps[0].start
    mask = ds.t>=start
    r = ds.response[mask]
    c = ds.steps[0].concentration
    if c in controls_dict:
        print('correcting c=',c)
        #analyte ref
        ds.response[mask] = np.subtract(r, controls_dict[c])
        #lig ref
        ds.response[mask] = np.subtract(ds.response[mask], exp.datasets[2].response[mask])
    
        

exp.plot()
# Out:
# 1.6e-05
# correcting c= 1.6e-05
# 8e-06
# correcting c= 8e-06
# 4e-06
# correcting c= 4e-06
# 1e-06
# correcting c= 1e-06
# 1e-06
# correcting c= 1e-06
# 2e-06
# correcting c= 2e-06
# 4e-06
# correcting c= 4e-06
# 8e-06
# correcting c= 8e-06
# 2e-06
# correcting c= 2e-06
# 1.6e-05
# correcting c= 1.6e-05
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
# exp.crop(3)

# %%
exp.interstep_correction()
exp.plot()
# Out:
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
#remove some datasets
ds_to_remove = []
for ds in exp:
    if ds.use_for_fit == False:
        ds_to_remove.append(ds)
for ds in ds_to_remove:
    exp.datasets.remove(ds)

# %%
exp.model = models.One_to_one()
exp.model.params_definitions
# Out:
# {'ka': <Parameter 'ka', value=10000.0, bounds=[10.0:10000000.0]>,
#  'kd': <Parameter 'kd', value=0.01, bounds=[1e-06:0.1]>,
#  'kt': <Parameter 'kt', value=10000000.0, bounds=[10.0:1000000000000.0]>,
#  'ymax': <Parameter 'ymax', value=1, bounds=[1e-12:1000]>,
#  'offset': <Parameter 'offset', value=0, bounds=[-1000:1000]>}

# %%
# exp.model.params_definitions['ymax'].user_data['type']='global'

exp.model.params_definitions['offset'].min= -0.1
exp.model.params_definitions['offset'].max= 0.1
exp.model.params_definitions['ymax'].max= 1
exp.model.params_definitions['ymax'].value= 0.25
exp.model.params_definitions['ka'].max= 1e5
exp.model.params_definitions['ka'].min= 100
exp.model.params_definitions['ka'].value = 5000



exp.create_params(offsets=True, mtl = False)


# # exp.model.params_definitions['ymax'].user_data['type']='global'

# #exp.model.params_definitions['ymax1'].user_data['type']='global'
# #exp.model.params_definitions['ymax2'].user_data['type']='global'

# exp.model.params_definitions['ka1'].value = 500
# exp.model.params_definitions['kd1'].min = 1e-12

# exp.create_params(offsets=1, mtl = 0)
# #exp.params

# %%
exp.fit_params()
# Out:
# fitting using: least_squares
# '`ftol` termination condition is satisfied.'

# %%
exp.plot(fit=True, correct_offsets=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
exp.result
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>least_squares</td><td></td></tr><tr><td># function evals</td><td>429</td><td></td></tr><tr><td># data points</td><td>21000</td><td></td></tr><tr><td># variables</td><td>32</td><td></td></tr><tr><td>chi-square</td><td> 11508.5962</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.54886476</td><td></td></tr><tr><td>Akaike info crit.</td><td>-12565.9919</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-12311.5190</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> ka </td><td>  4689.16873 </td><td>  6280.82595 </td><td> (133.94%) </td><td> 5000 </td><td>  100.000000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> kd </td><td>  0.03867410 </td><td>  0.02638745 </td><td> (68.23%) </td><td> 0.01 </td><td>  1.0000e-06 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> ymax_ds5 </td><td>  0.34171379 </td><td>  0.23764510 </td><td> (69.55%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds6 </td><td>  0.29051748 </td><td>  0.30998171 </td><td> (106.70%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds7 </td><td>  0.32320975 </td><td>  0.46377106 </td><td> (143.49%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds9 </td><td>  0.24464306 </td><td>  0.88639470 </td><td> (362.32%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds10 </td><td>  0.52612083 </td><td>  1.14480195 </td><td> (217.59%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds11 </td><td>  0.46892019 </td><td>  0.79521598 </td><td> (169.58%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds12 </td><td>  0.39899840 </td><td>  0.53721134 </td><td> (134.64%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds13 </td><td>  0.28190804 </td><td>  0.30423068 </td><td> (107.92%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds15 </td><td>  0.35517525 </td><td>  0.66959471 </td><td> (188.53%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds16 </td><td>  0.25363520 </td><td>  0.20266482 </td><td> (79.90%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> offset_ds5_step0 </td><td>  0.03248368 </td><td>  0.10406177 </td><td> (320.35%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds5_step1 </td><td>  0.10000000 </td><td>  0.04662005 </td><td> (46.62%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds6_step0 </td><td>  0.05453865 </td><td>  0.09154255 </td><td> (167.85%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds6_step1 </td><td>  0.05346792 </td><td>  0.04018245 </td><td> (75.15%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds7_step0 </td><td>  0.04392721 </td><td>  0.08405444 </td><td> (191.35%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds7_step1 </td><td>  0.03040851 </td><td>  0.03784855 </td><td> (124.47%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds9_step0 </td><td>  0.04426112 </td><td>  0.07638320 </td><td> (172.57%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds9_step1 </td><td>  0.07299799 </td><td>  0.03554952 </td><td> (48.70%) </td><td> 0 </td><td> -0.10000000 </td>< ...

# %%
import plotly.graph_objects as go

fig = go.Figure()

for ds in exp.datasets:
    if ds.use_for_fit == False: continue
    x = np.array([])
    y = np.array([])
    y_fit = np.array([])
    
    for step in ds.steps:
        # if step.concentration>0: color = 'orangered'
        # elif step.concentration==0: color = 'cornflowerBlue'
        # else: color = 'lightgrey'
        mask = (ds.t>=step.start) & (ds.t<step.stop)

        if f"offset_ds{ds.index}_step{step.index}" in exp.params:
                offset = exp.params[f'offset_ds{ds.index}_step{step.index}'].value
        else: 
            offset = 0
        
        x_step = ds.t[mask]
        y_step = ds.response[mask] - offset
        y_fit_step = ds.fit_response[mask] - offset

        x = np.concatenate([x, x_step])
        y = np.concatenate([y, y_step])
        y_fit = np.concatenate([y_fit, y_fit_step])

    
    x = x - x[0]
    fig.add_scatter(x = x, 
                    y = y_fit,
                    marker=dict(size=0, 
                            color='black',
                            line=dict(width=1, color='black')),
                    line=dict(
                         width=2, 
                         color='black'
                         ),
                    name=ds.steps[0].concentration,)

        

    fig.add_scatter(x = x,
                    y = y,
                    marker=dict(
                            size=0, 
                            #color=color, 
                            line=dict(
                                    width=0.1, 
                                    #color=color
                                    )),
                    line=dict(
                            width=1, 
                            #color=color
                            ),
                    name=f"{ds.index}_{ds.steps[0].concentration}",
                    )



fig.update_layout(
            height=600,
            width = 800,
            font_family="Arial",
            font_size = 24,
            showlegend=False,
            margin=dict(l=0,r=0,b=0,t=0,pad=0), 
            template='plotly_white',
            paper_bgcolor="rgb(255, 255, 255)",  
            plot_bgcolor="rgb(255, 255, 255)") 

fig.update_xaxes(
    ticklabelposition="inside top", 
    title='time [s]',
    showline=True, 
    linewidth=1, 
    linecolor='black', 
    showgrid=False,
    mirror=True)

fig.update_yaxes(
    ticklabelposition="outside top", 
    title='Response [nm]',
    showline=True, 
    linewidth=1, 
    linecolor='black', 
    showgrid=False,
    mirror=True)



fig.show()

# %%
for ds in exp:
    ds.use_for_fit = True

# %%
for ds in exp:
    if ds.index in [9, 15, 6, 5, 12]:
        ds.use_for_fit = False
    if ds.index in []:
        ds.use_for_fit = True
    # if ds.steps[0].concentration==16e-6:
    #     ds.use_for_fit = True

# %%
exp.crop(3)

# %%
0.03867410/4689.16873
# Out:
# 8.247538578122352e-06

# %%
exp.result
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>least_squares</td><td></td></tr><tr><td># function evals</td><td>429</td><td></td></tr><tr><td># data points</td><td>21000</td><td></td></tr><tr><td># variables</td><td>32</td><td></td></tr><tr><td>chi-square</td><td> 11508.5962</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.54886476</td><td></td></tr><tr><td>Akaike info crit.</td><td>-12565.9919</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-12311.5190</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> ka </td><td>  4689.16873 </td><td>  6280.82595 </td><td> (133.94%) </td><td> 5000 </td><td>  100.000000 </td><td>  100000.000 </td><td> True </td></tr><tr><td> kd </td><td>  0.03867410 </td><td>  0.02638745 </td><td> (68.23%) </td><td> 0.01 </td><td>  1.0000e-06 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> ymax_ds5 </td><td>  0.34171379 </td><td>  0.23764510 </td><td> (69.55%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds6 </td><td>  0.29051748 </td><td>  0.30998171 </td><td> (106.70%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds7 </td><td>  0.32320975 </td><td>  0.46377106 </td><td> (143.49%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds9 </td><td>  0.24464306 </td><td>  0.88639470 </td><td> (362.32%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds10 </td><td>  0.52612083 </td><td>  1.14480195 </td><td> (217.59%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds11 </td><td>  0.46892019 </td><td>  0.79521598 </td><td> (169.58%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds12 </td><td>  0.39899840 </td><td>  0.53721134 </td><td> (134.64%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds13 </td><td>  0.28190804 </td><td>  0.30423068 </td><td> (107.92%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds15 </td><td>  0.35517525 </td><td>  0.66959471 </td><td> (188.53%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> ymax_ds16 </td><td>  0.25363520 </td><td>  0.20266482 </td><td> (79.90%) </td><td> 0.25 </td><td>  1.0000e-12 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> offset_ds5_step0 </td><td>  0.03248368 </td><td>  0.10406177 </td><td> (320.35%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds5_step1 </td><td>  0.10000000 </td><td>  0.04662005 </td><td> (46.62%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds6_step0 </td><td>  0.05453865 </td><td>  0.09154255 </td><td> (167.85%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds6_step1 </td><td>  0.05346792 </td><td>  0.04018245 </td><td> (75.15%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds7_step0 </td><td>  0.04392721 </td><td>  0.08405444 </td><td> (191.35%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds7_step1 </td><td>  0.03040851 </td><td>  0.03784855 </td><td> (124.47%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds9_step0 </td><td>  0.04426112 </td><td>  0.07638320 </td><td> (172.57%) </td><td> 0 </td><td> -0.10000000 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> offset_ds9_step1 </td><td>  0.07299799 </td><td>  0.03554952 </td><td> (48.70%) </td><td> 0 </td><td> -0.10000000 </td>< ...

# %%
import kaleido
exp_name = "GST-D1_E3-HLM"
fig.write_image(f'{exp_name}.png')

# %%
report_filename = 'gst-d1-hlm_e3-lsm'

from lmfit.printfuncs import fitreport_html_table
s = fitreport_html_table(exp.result, show_correl=True,  min_correl=0.1)

with open(f"{exp_name}.htm", 'w') as f:
    f.write(s)

# %%
from uncertainties import ufloat
def get_html_report(show_correl=True):
    result = exp.result
    tables = result._repr_html_(show_correl=show_correl)
    
    if ('ka' in result.params) and ('kd' in result.params):
        t = []
        cell = lambda x, tag: f'<{tag}> {x} </{tag}>'
        
        has_er = hasattr(result.params['ka'], 'stderr') and (result.params['ka'].stderr is not None)

        if has_er:
            ka = ufloat(float(result.params['ka'].value), float(result.params['ka'].stderr))
            kd = ufloat(float(result.params['kd'].value), float(result.params['kd'].stderr))
            Kd = kd/ka
        else:
            Kd = result.params['kd'].value/result.params['ka'].value

        t.append('<h2>Dissociation constant</h2>')
        t.append('<table><tr>')
        t.append(cell(f"<b>Name</b>", 'td'))
        t.append(cell(f"<b>value</b>", 'td'))
        t.append(cell(f"<b>standard error</b>", 'td'))
        t.append(cell(f"<b>relative error</b>", 'td'))  
        t.append('</tr><tr>')
        t.append(cell(f"<b>Kd</b>", 'td'))
        if has_er:
            t.append(cell(f"{Kd.n:.5e}", 'td'))
            t.append(cell(f"{Kd.std_dev:.5e}", 'td'))
            t.append(cell(f"{Kd.std_dev/Kd.n:.2%}", 'td'))
        else:
            t.append(cell(f"{Kd:.5e}", 'td'))
            t.append(cell("NA", 'td'))
            t.append(cell("NA", 'td'))
        t.append('</table></tr></table>')

        return tables + ''.join(t)
    
    else: 
        return tables

report = get_html_report(show_correl=False)
with open(f'{exp_name}extended_report.htm','w') as f:
    f.write(report)

# %%
pars2 = exp.result.params.copy()
to_remove = []
for k,v in pars2.items():
    if any([x in k for x in "ka kd ymax".split() ]): 
        pass
    else:
        to_remove.append(k)
for k in to_remove:
    pars2.pop(k)
pars2
# Out:
# Parameters([('ka', <Parameter 'ka', value=4689.168727487891 +/- 6.28e+03, bounds=[100:100000.0]>), ('kd', <Parameter 'kd', value=0.03867410325395835 +/- 0.0264, bounds=[1e-06:0.1]>), ('ymax_ds5', <Parameter 'ymax_ds5', value=0.3417137864562915 +/- 0.238, bounds=[1e-12:1]>), ('ymax_ds6', <Parameter 'ymax_ds6', value=0.2905174782099406 +/- 0.31, bounds=[1e-12:1]>), ('ymax_ds7', <Parameter 'ymax_ds7', value=0.3232097460574698 +/- 0.464, bounds=[1e-12:1]>), ('ymax_ds9', <Parameter 'ymax_ds9', value=0.24464306240184405 +/- 0.886, bounds=[1e-12:1]>), ('ymax_ds10', <Parameter 'ymax_ds10', value=0.5261208315837128 +/- 1.14, bounds=[1e-12:1]>), ('ymax_ds11', <Parameter 'ymax_ds11', value=0.4689201880171658 +/- 0.795, bounds=[1e-12:1]>), ('ymax_ds12', <Parameter 'ymax_ds12', value=0.39899839713318946 +/- 0.537, bounds=[1e-12:1]>), ('ymax_ds13', <Parameter 'ymax_ds13', value=0.281908042407809 +/- 0.304, bounds=[1e-12:1]>), ('ymax_ds15', <Parameter 'ymax_ds15', value=0.35517524695054487 +/- 0.67, bounds=[1e-12:1]>), ('ymax_ds16', <Parameter 'ymax_ds16', value=0.25363520040236875 +/- 0.203, bounds=[1e-12:1]>)])

# %%
sim = Exp()
concs = [1, 2, 4, 8, 16, 1000000]
concs = [c*1e-6 for c in concs]
for c in concs:
    sim.add_dataset(np.linspace(0,1000,1000), np.linspace(1000,2000,1000))
    sim.datasets[-1].add_step(0, 500, c)
    sim.datasets[-1].add_step(500, 1000, 0)

# %%
sim.plot()
# Out:
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %%
sim.model = models.One_to_one()
sim.model.params_definitions['ymax'].user_data['type']='global'
sim.create_params()

# %%
sim.params
# Out:
# Parameters([('ka', <Parameter 'ka', value=10000.0, bounds=[10.0:10000000.0]>), ('kd', <Parameter 'kd', value=0.01, bounds=[1e-06:0.1]>), ('ymax', <Parameter 'ymax', value=1, bounds=[1e-12:1000]>)])

# %%
sim.params['ka'] = exp.params['ka']
sim.params['kd'] = exp.params['kd']
sim.params['ymax'] = exp.params['ymax_ds5']
sim.params['ymax'].value = 0.25

# %%
sim.params
# Out:
# Parameters([('ka', <Parameter 'ka', value=4689.168727487891 +/- 6.28e+03, bounds=[100:100000.0]>), ('kd', <Parameter 'kd', value=0.03867410325395835 +/- 0.0264, bounds=[1e-06:0.1]>), ('ymax', <Parameter 'ymax', value=0.25 +/- 0.238, bounds=[1e-12:1]>)])

# %%
sim.simulate_response(None, 0, 0)

# %%
sim.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)
