# %%
import importlib
import experiment
importlib.reload(experiment)
import models
importlib.reload(models)

from experiment import *

# %%
exp_name = "GST-D1-HLM_E3-FL"

from pathlib import Path
path = Path("./data/GST-D1-HLM_E3-FL_230105/redoGST-DCP1-HLM_VS_EDC3-FL")
fs = sorted(list(path.glob("*.csv")))

controls_path = Path("./data/GST-D1-HLM_E3-FL_230105/refs")
controls_fs = sorted(list(controls_path.glob("*.csv")))
print(len(fs))
print(len(controls_fs))
# Out:
# 20
# 5

# %%
exp = Exp()
exp.load_bli_data(fs)

#remove loading and baselines because you forgot to do that in exp class 
for ds in exp:
    s = ds.steps[0].start
    mask = ds.t >= s
    ds.response = ds.response[mask]
    ds.t = ds.t[mask]
    
# exp.plot()

# %%
controls = Exp()
controls.load_bli_data(controls_fs)
controls.interstep_correction()
# controls.plot()

# %%
#load descriptions, need to copy from blitz or include it manually
desc = Path(f"./data/GST-D1-HLM_E3-FL_230105/dataset_description.txt")
df = pd.read_csv(desc, sep='\t', index_col=0)
# df

# %%
#assign concentrations from desc to each dataset
concs = df['Conc. (uM)'].to_dict()
analyze = df['Analyze'].to_dict()

for ds in exp.datasets:
    idx = ds.name[:-4].split('_')[-1]
    idx=int(idx)
    c = concs[idx]
    if np.isnan(c): c=0
    ds.steps[0].concentration = c*1e-6
    ds.use_for_fit = analyze[idx]

# %%
for ds in exp.datasets:
    print(ds)
exp.interstep_correction()
# exp.plot()
# Out:
# Dataset(0, name = 2023-01-05_001.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(1, name = 2023-01-05_002.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(2, name = 2023-01-05_003.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(3, name = 2023-01-05_004.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(4, name = 2023-01-05_005.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(5, name = 2023-01-05_006.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(6, name = 2023-01-05_007.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(7, name = 2023-01-05_008.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(8, name = 2023-01-05_009.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(9, name = 2023-01-05_010.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(10, name = 2023-01-05_011.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(11, name = 2023-01-05_012.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 0)
# Dataset(12, name = 2023-01-05_013.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(13, name = 2023-01-05_014.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(14, name = 2023-01-05_015.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(15, name = 2023-01-05_016.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(16, name = 2023-01-05_017.csv, no_steps = 2, len = 509.79999999999995, baseline = (30.0, 230.0), use_for_fit = 0)
# Dataset(17, name = 2023-01-05_018.csv, no_steps = 2, len = 509.79999999999995, baseline = (30.0, 230.0), use_for_fit = 0)
# Dataset(18, name = 2023-01-05_019.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)
# Dataset(19, name = 2023-01-05_020.csv, no_steps = 2, len = 479.79999999999995, baseline = (230.0, 260.0), use_for_fit = 1)

# %%
#assign conentrations to controls
controls_c = [0.,0.2,0.4,0.8,1.6]
controls_c = [c*1e-6 for c in controls_c]

for ds, c in zip(controls, controls_c):
    ds.steps[0].concentration = c

# %%
controls_dict = {}
for ds in controls:
    control_mask = ds.t>=ds.steps[0].start
    c = ds.steps[0].concentration
    controls_dict[c] = ds.response[control_mask]

#subtract controls from ds
for ds in exp:
    if not ds.use_for_fit: continue
    print(ds.steps[0].concentration)
    start = ds.steps[0].start
    mask = ds.t>=start
    r = ds.response[mask]
    c = ds.steps[0].concentration
    if c in controls_dict:
        print('correcting c=',c)
        ds.response[mask] = np.subtract(r, controls_dict[c])
        

# exp.plot()
# Out:
# 1.6e-06
# correcting c= 1.6e-06
# 1.6e-06
# correcting c= 1.6e-06
# 8e-07
# correcting c= 8e-07
# 4e-07
# correcting c= 4e-07
# 8e-07
# correcting c= 8e-07
# 2e-07
# correcting c= 2e-07
# 2e-07
# correcting c= 2e-07
# 1e-07
# 1e-07
# 8e-07
# correcting c= 8e-07
# 4e-07
# correcting c= 4e-07

# %%
# exp.crop(3)

# %%
exp.interstep_correction()
exp.plot()
# Out:
# Exp.params is None. Fit and offset plots are not available
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
#remove some datasets
ds_to_remove = []#[15, 12, 19, 18, 0, 3]
for ds in exp:
    if ds.use_for_fit == False:
        ds_to_remove.append(ds)
for ds in ds_to_remove:
    exp.datasets.remove(ds)

# %%
exp.model = models.Bivalent_analyte()
exp.model.params_definitions
# Out:
# {'ka1': <Parameter 'ka1', value=10000.0, bounds=[10.0:100000000.0]>,
#  'kd1': <Parameter 'kd1', value=0.01, bounds=[1e-06:0.1]>,
#  'ka2': <Parameter 'ka2', value=0.01, bounds=[1e-07:10000000.0]>,
#  'kd2': <Parameter 'kd2', value=0.01, bounds=[1e-07:10000000.0]>,
#  'kt': <Parameter 'kt', value=10000000.0, bounds=[10.0:1000000000000.0]>,
#  'ymax': <Parameter 'ymax', value=1, bounds=[0:1000]>,
#  'offset': <Parameter 'offset', value=0, bounds=[-1000:1000]>}

# %%
# exp.model.params_definitions['ymax'].user_data['type']='global'

# exp.model.params_definitions['ymax1'].user_data['type']='global'
# exp.model.params_definitions['ymax2'].user_data['type']='global'

exp.create_params(offsets=1, mtl = 0)
exp.params
# Out:
# Parameters([('ka1', <Parameter 'ka1', value=10000.0, bounds=[10.0:100000000.0]>), ('kd1', <Parameter 'kd1', value=0.01, bounds=[1e-06:0.1]>), ('ka2', <Parameter 'ka2', value=0.01, bounds=[1e-07:10000000.0]>), ('kd2', <Parameter 'kd2', value=0.01, bounds=[1e-07:10000000.0]>), ('ymax_ds0', <Parameter 'ymax_ds0', value=1, bounds=[0:1000]>), ('ymax_ds1', <Parameter 'ymax_ds1', value=1, bounds=[0:1000]>), ('ymax_ds3', <Parameter 'ymax_ds3', value=1, bounds=[0:1000]>), ('ymax_ds6', <Parameter 'ymax_ds6', value=1, bounds=[0:1000]>), ('ymax_ds9', <Parameter 'ymax_ds9', value=1, bounds=[0:1000]>), ('ymax_ds12', <Parameter 'ymax_ds12', value=1, bounds=[0:1000]>), ('ymax_ds13', <Parameter 'ymax_ds13', value=1, bounds=[0:1000]>), ('ymax_ds14', <Parameter 'ymax_ds14', value=1, bounds=[0:1000]>), ('ymax_ds15', <Parameter 'ymax_ds15', value=1, bounds=[0:1000]>), ('ymax_ds18', <Parameter 'ymax_ds18', value=1, bounds=[0:1000]>), ('ymax_ds19', <Parameter 'ymax_ds19', value=1, bounds=[0:1000]>), ('offset_ds0_step0', <Parameter 'offset_ds0_step0', value=0, bounds=[-1000:1000]>), ('offset_ds0_step1', <Parameter 'offset_ds0_step1', value=0, bounds=[-1000:1000]>), ('offset_ds1_step0', <Parameter 'offset_ds1_step0', value=0, bounds=[-1000:1000]>), ('offset_ds1_step1', <Parameter 'offset_ds1_step1', value=0, bounds=[-1000:1000]>), ('offset_ds3_step0', <Parameter 'offset_ds3_step0', value=0, bounds=[-1000:1000]>), ('offset_ds3_step1', <Parameter 'offset_ds3_step1', value=0, bounds=[-1000:1000]>), ('offset_ds6_step0', <Parameter 'offset_ds6_step0', value=0, bounds=[-1000:1000]>), ('offset_ds6_step1', <Parameter 'offset_ds6_step1', value=0, bounds=[-1000:1000]>), ('offset_ds9_step0', <Parameter 'offset_ds9_step0', value=0, bounds=[-1000:1000]>), ('offset_ds9_step1', <Parameter 'offset_ds9_step1', value=0, bounds=[-1000:1000]>), ('offset_ds12_step0', <Parameter 'offset_ds12_step0', value=0, bounds=[-1000:1000]>), ('offset_ds12_step1', <Parameter 'offset_ds12_step1', value=0, bounds=[-1000:1000]>), ('offset_ds13_step0', <Parameter 'offset_ds13_step0', value=0, bounds=[-1000:1000]>), ('offset_ds13_step1', <Parameter 'offset_ds13_step1', value=0, bounds=[-1000:1000]>), ('offset_ds14_step0', <Parameter 'offset_ds14_step0', value=0, bounds=[-1000:1000]>), ('offset_ds14_step1', <Parameter 'offset_ds14_step1', value=0, bounds=[-1000:1000]>), ('offset_ds15_step0', <Parameter 'offset_ds15_step0', value=0, bounds=[-1000:1000]>), ('offset_ds15_step1', <Parameter 'offset_ds15_step1', value=0, bounds=[-1000:1000]>), ('offset_ds18_step0', <Parameter 'offset_ds18_step0', value=0, bounds=[-1000:1000]>), ('offset_ds18_step1', <Parameter 'offset_ds18_step1', value=0, bounds=[-1000:1000]>), ('offset_ds19_step0', <Parameter 'offset_ds19_step0', value=0, bounds=[-1000:1000]>), ('offset_ds19_step1', <Parameter 'offset_ds19_step1', value=0, bounds=[-1000:1000]>)])

# %%
exp.fit_params()
# Out:
# fitting using: least_squares
# '`ftol` termination condition is satisfied.'

# %%
flag = False
for par in exp.params:
    if "offset" in par:
        flag=True

exp.plot(fit=True, correct_offsets=flag)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
import plotly.graph_objects as go

fig = go.Figure()

for ds in exp.datasets:
    if ds.use_for_fit == False: continue
    x = np.array([])
    y = np.array([])
    y_fit = np.array([])
    
    for step in ds.steps:
        # if step.concentration>0: color = 'orangered'
        # elif step.concentration==0: color = 'cornflowerBlue'
        # else: color = 'lightgrey'
        mask = (ds.t>=step.start) & (ds.t<step.stop)

        if f"offset_ds{ds.index}_step{step.index}" in exp.params:
                offset = exp.params[f'offset_ds{ds.index}_step{step.index}'].value
        else: 
            offset = 0
        
        x_step = ds.t[mask]
        y_step = ds.response[mask] - offset
        y_fit_step = ds.fit_response[mask] - offset

        x = np.concatenate([x, x_step])
        y = np.concatenate([y, y_step])
        y_fit = np.concatenate([y_fit, y_fit_step])

    
    x = x - x[0]
    fig.add_scatter(x = x, 
                    y = y_fit,
                    marker=dict(size=0, 
                            color='black',
                            line=dict(width=1, color='black')),
                    line=dict(
                         width=2, 
                         color='black'
                         ),
                    name=ds.steps[0].concentration,)

        

    fig.add_scatter(x = x,
                    y = y,
                    marker=dict(
                            size=0, 
                            #color=color, 
                            line=dict(
                                    width=0.1, 
                                    #color=color
                                    )),
                    line=dict(
                            width=1, 
                            #color=color
                            ),
                    name=f"{ds.index}_{ds.steps[0].concentration}",
                    )



fig.update_layout(
            height=600,
            width = 800,
            font_family="Arial",
            font_size = 24,
            showlegend=False,
            margin=dict(l=0,r=0,b=0,t=0,pad=0), 
            template='plotly_white',
            paper_bgcolor="rgb(255, 255, 255)",  
            plot_bgcolor="rgb(255, 255, 255)") 

fig.update_xaxes(
    ticklabelposition="inside top", 
    title='czas [s]',
    showline=True, 
    linewidth=1, 
    linecolor='black', 
    showgrid=False,
    mirror=True)

fig.update_yaxes(
    ticklabelposition="outside top", 
    title='Sygnał [nm]',
    showline=True, 
    linewidth=1, 
    linecolor='black', 
    showgrid=False,
    mirror=True)



fig.show()

# %%
for ds in exp:
    if ds.index in [15, 12, 19, 18, 0, 3]:
        ds.use_for_fit = False
    if ds.index in [6]:
        ds.use_for_fit = True
    # if ds.steps[0].concentration==16e-6:
    #     ds.use_for_fit = True
[ds.index for ds in exp]
# Out:
# [0, 1, 3, 6, 9, 12, 13, 14, 15, 18, 19]

# %%
exp.crop(3)

# %%
exp.model.name
# Out:
# 'Bivalent analyte'

# %%
import kaleido
exp_name = "GST-D1_E3-FL"
fig.write_image(f'{exp_name}-{exp.model.name}.png')

# %%
from lmfit.printfuncs import fitreport_html_table
s = fitreport_html_table(exp.result, show_correl=True,  min_correl=0.1)

with open(f"{exp_name}-{exp.model.name}.htm", 'w') as f:
    f.write(s)

# %%
from uncertainties import ufloat
def get_html_report(show_correl=True):
    result = exp.result
    tables = result._repr_html_(show_correl=show_correl)
    
    if ('ka' in result.params) and ('kd' in result.params):
        t = []
        cell = lambda x, tag: f'<{tag}> {x} </{tag}>'
        
        has_er = hasattr(result.params['ka'], 'stderr') and (result.params['ka'].stderr is not None)

        if has_er:
            ka = ufloat(float(result.params['ka'].value), float(result.params['ka'].stderr))
            kd = ufloat(float(result.params['kd'].value), float(result.params['kd'].stderr))
            Kd = kd/ka
        else:
            Kd = result.params['kd'].value/result.params['ka'].value

        t.append('<h2>Dissociation constant</h2>')
        t.append('<table><tr>')
        t.append(cell(f"<b>Name</b>", 'td'))
        t.append(cell(f"<b>value</b>", 'td'))
        t.append(cell(f"<b>standard error</b>", 'td'))
        t.append(cell(f"<b>relative error</b>", 'td'))  
        t.append('</tr><tr>')
        t.append(cell(f"<b>Kd</b>", 'td'))
        if has_er:
            t.append(cell(f"{Kd.n:.5e}", 'td'))
            t.append(cell(f"{Kd.std_dev:.5e}", 'td'))
            t.append(cell(f"{Kd.std_dev/Kd.n:.2%}", 'td'))
        else:
            t.append(cell(f"{Kd:.5e}", 'td'))
            t.append(cell("NA", 'td'))
            t.append(cell("NA", 'td'))
        t.append('</table></tr></table>')

        return tables + ''.join(t)
    
    else: 
        return tables

report = get_html_report(show_correl=False)
with open(f'{exp_name}-{exp.model.name}-extended_report.htm','w') as f:
    f.write(report)

# %%
from PIL import Image

# Open the images
image1 = Image.open('GST-D1_E3-FL-Bivalent analyte.png')
image2 = Image.open('GST-D1_E3-FL-Heterogeneous ligand.png')

# Get the dimensions of the images
width1, height1 = image1.size
width2, height2 = image2.size

# Create a new image with a width equal to the sum of the widths of the two images plus 10px
# and a height equal to the maximum height of the two images
new_image = Image.new('RGB', (width1 + width2 + 10, max(height1, height2)), color='white')

# Paste the first image at position (0, 0)
new_image.paste(image1, (0, 0))

# Paste the second image at position (width1 + 10, 0)
new_image.paste(image2, (width1 + 10, 0))

# Save the new image
new_image.save('GST-D1_E3-FL.png')

# %%
from uncertainties import ufloat

# %%
# pars = exp.result.params

# ka1 = pars['ka1'].value
# ka1_er = ka1*25.05/100
# kd1 = pars['kd1'].value
# ka2 = pars['ka2'].value
# kd2 = pars['kd2'].value

# Kd = (kd1 * kd2) / (ka1 * ka2)

# %%
exp.model.name
# Out:
# 'Heterogeneous ligand'

# %%
vals = []
for par in exp.params:
    if 'ymax' in par:
        vals.append(exp.params[par].value)
print(np.average(vals))
# Out:
# 1.4331185488596245

# %%
exp.model.name
# Out:
# 'Bivalent analyte'

# %%
3.4615e-04	/0.02554522
# Out:
# 2.404034041459876e-06

# %%
exp.model.name
# Out:
# 'Bivalent analyte'

# %%
exp.result.params
# Out:
# Parameters([('ka1', <Parameter 'ka1', value=14226.487447433365 +/- 58.2, bounds=[10.0:100000000.0]>), ('kd1', <Parameter 'kd1', value=0.034200956378648825 +/- 0.000253, bounds=[1e-06:0.1]>), ('ka2', <Parameter 'ka2', value=0.02554521713107189 +/- 0.000182, bounds=[1e-07:10000000.0]>), ('kd2', <Parameter 'kd2', value=0.00034614617943268527 +/- 2e-06, bounds=[1e-07:10000000.0]>), ('ymax_ds0', <Parameter 'ymax_ds0', value=1.4705903145280743 +/- 0.00312, bounds=[0:1000]>), ('ymax_ds1', <Parameter 'ymax_ds1', value=1.6562234333641472 +/- 0.00323, bounds=[0:1000]>), ('ymax_ds3', <Parameter 'ymax_ds3', value=1.5218169632624106 +/- 0.0034, bounds=[0:1000]>), ('ymax_ds6', <Parameter 'ymax_ds6', value=1.261005346964441 +/- 0.00388, bounds=[0:1000]>), ('ymax_ds9', <Parameter 'ymax_ds9', value=1.3600812651006446 +/- 0.00327, bounds=[0:1000]>), ('ymax_ds12', <Parameter 'ymax_ds12', value=1.374192983886093 +/- 0.00504, bounds=[0:1000]>), ('ymax_ds13', <Parameter 'ymax_ds13', value=1.3993834038166362 +/- 0.00507, bounds=[0:1000]>), ('ymax_ds14', <Parameter 'ymax_ds14', value=1.675723635950408 +/- 0.00702, bounds=[0:1000]>), ('ymax_ds15', <Parameter 'ymax_ds15', value=1.6847052572678682 +/- 0.00703, bounds=[0:1000]>), ('ymax_ds18', <Parameter 'ymax_ds18', value=1.1683599980417887 +/- 0.00313, bounds=[0:1000]>), ('ymax_ds19', <Parameter 'ymax_ds19', value=1.192221435273358 +/- 0.00381, bounds=[0:1000]>), ('offset_ds0_step0', <Parameter 'offset_ds0_step0', value=-0.028235108252729547 +/- 0.00221, bounds=[-1000:1000]>), ('offset_ds0_step1', <Parameter 'offset_ds0_step1', value=0.05951011921552516 +/- 0.00229, bounds=[-1000:1000]>), ('offset_ds1_step0', <Parameter 'offset_ds1_step0', value=-0.18536852367896034 +/- 0.00234, bounds=[-1000:1000]>), ('offset_ds1_step1', <Parameter 'offset_ds1_step1', value=-0.13341343600484526 +/- 0.00239, bounds=[-1000:1000]>), ('offset_ds3_step0', <Parameter 'offset_ds3_step0', value=-0.06370569395871664 +/- 0.00162, bounds=[-1000:1000]>), ('offset_ds3_step1', <Parameter 'offset_ds3_step1', value=0.004461866371701141 +/- 0.00175, bounds=[-1000:1000]>), ('offset_ds6_step0', <Parameter 'offset_ds6_step0', value=0.02785844400533659 +/- 0.00118, bounds=[-1000:1000]>), ('offset_ds6_step1', <Parameter 'offset_ds6_step1', value=0.007182076879858657 +/- 0.0015, bounds=[-1000:1000]>), ('offset_ds9_step0', <Parameter 'offset_ds9_step0', value=-0.026602871411549083 +/- 0.00156, bounds=[-1000:1000]>), ('offset_ds9_step1', <Parameter 'offset_ds9_step1', value=-0.02030160286966832 +/- 0.00172, bounds=[-1000:1000]>), ('offset_ds12_step0', <Parameter 'offset_ds12_step0', value=-0.0017788093124810058 +/- 0.00101, bounds=[-1000:1000]>), ('offset_ds12_step1', <Parameter 'offset_ds12_step1', value=-0.05069244616007123 +/- 0.00147, bounds=[-1000:1000]>), ('offset_ds13_step0', <Parameter 'offset_ds13_step0', value=-0.016492227836778447 +/- 0.00101, bounds=[-1000:1000]>), ('offset_ds13_step1', <Parameter 'offset_ds13_step1', value=-0.0505678003317379 +/- 0.00147, bounds=[-1000:1000]>), ('offset_ds14_step0', <Parameter 'offset_ds14_step0', value=-0.07189356649177926 +/- 0.000932, bounds=[-1000:1000]>), ('offset_ds14_step1', <Parameter 'offset_ds14_step1', value=-0.11076623017692613 +/- 0.00149, bounds=[-1000:1000]>), ('offset_ds15_step0', <Parameter 'offset_ds15_step0', value=-0.05405938141848135 +/- 0.000932, bounds=[-1000:1000]>), ('offset_ds15_step1', <Parameter 'offset_ds15_step1', value=-0.12488832246067652 +/- 0.00149, bounds=[-1000:1000]>), ('offset_ds18_step0', <Parameter 'offset_ds18_step0', value=0.011379008198921911 +/- 0.00149, bounds=[-1000:1000]>), ('offset_ds18_step1', <Parameter 'offset_ds18_step1', value=0.04475974888513944 +/- 0.00168, bounds=[-1000:1000]>), ('offset_ds19_step0', <Parameter 'offset_ds19_step0', value=0.0582522717749843 +/- 0.00117, bounds=[-1000:1000]>), ('offset_ds19_step1', <Parameter 'offset_ds19_step1', value=0.015029400384825161 +/- 0.0015, bounds=[-1000:1000]>)])

# %%
params = exp.params

y = np.var(np.concatenate([dataset.response for dataset in exp.datasets]).flatten(), ddof=2)
1 - exp.result.redchi / y
# Out:
# 0.9985380268941834

# %%
exp.model.name
# Out:
# 'Bivalent analyte'

# %%
exp.result
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>least_squares</td><td></td></tr><tr><td># function evals</td><td>1492</td><td></td></tr><tr><td># data points</td><td>26400</td><td></td></tr><tr><td># variables</td><td>37</td><td></td></tr><tr><td>chi-square</td><td> 4.41062075</td><td></td></tr><tr><td>reduced chi-square</td><td> 1.6730e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-229529.542</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-229226.840</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> ka1 </td><td>  14226.4874 </td><td>  58.1821880 </td><td> (0.41%) </td><td> 10000.0 </td><td>  10.0000000 </td><td>  1.0000e+08 </td><td> True </td></tr><tr><td> kd1 </td><td>  0.03420096 </td><td>  2.5319e-04 </td><td> (0.74%) </td><td> 0.01 </td><td>  1.0000e-06 </td><td>  0.10000000 </td><td> True </td></tr><tr><td> ka2 </td><td>  0.02554522 </td><td>  1.8159e-04 </td><td> (0.71%) </td><td> 0.01 </td><td>  1.0000e-07 </td><td>  10000000.0 </td><td> True </td></tr><tr><td> kd2 </td><td>  3.4615e-04 </td><td>  2.0002e-06 </td><td> (0.58%) </td><td> 0.01 </td><td>  1.0000e-07 </td><td>  10000000.0 </td><td> True </td></tr><tr><td> ymax_ds0 </td><td>  1.47059031 </td><td>  0.00311852 </td><td> (0.21%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds1 </td><td>  1.65622343 </td><td>  0.00322676 </td><td> (0.19%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds3 </td><td>  1.52181696 </td><td>  0.00339799 </td><td> (0.22%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds6 </td><td>  1.26100535 </td><td>  0.00388452 </td><td> (0.31%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds9 </td><td>  1.36008127 </td><td>  0.00327475 </td><td> (0.24%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds12 </td><td>  1.37419298 </td><td>  0.00503590 </td><td> (0.37%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds13 </td><td>  1.39938340 </td><td>  0.00507167 </td><td> (0.36%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds14 </td><td>  1.67572364 </td><td>  0.00701600 </td><td> (0.42%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds15 </td><td>  1.68470526 </td><td>  0.00702878 </td><td> (0.42%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds18 </td><td>  1.16836000 </td><td>  0.00313110 </td><td> (0.27%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> ymax_ds19 </td><td>  1.19222144 </td><td>  0.00380541 </td><td> (0.32%) </td><td> 1 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> offset_ds0_step0 </td><td> -0.02823511 </td><td>  0.00221097 </td><td> (7.83%) </td><td> 0 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> offset_ds0_step1 </td><td>  0.05951012 </td><td>  0.00229126 </td><td> (3.85%) </td><td> 0 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> offset_ds1_step0 </td><td> -0.18536852 </td><td>  0.00234088 </td><td> (1.26%) </td><td> 0 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> offset_ds1_step1 </td><td> -0.13341344 </td><td>  0.00239421 </td><td> (1.79%) </td><td> 0 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> offset_ds3_step0 </td><td> -0.06370569 </td><td>  0.00161718 </td><td> (2.54%) </td><td> 0 </td><td> -1000.00000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> offset_ds3_step1 </td><td>  0.004461 ...

# %%
params = exp.params
y = np.concatenate([dataset.response for dataset in exp.datasets]).flatten()
mask = ~np.isnan(y)
y=y[mask]
y = np.var(y, ddof=2)

1 - exp.result.redchi / y
# Out:
# 0.9979720646749575

# %%
np.concatenate([dataset.response for dataset in exp.datasets]).flatten()
# Out:
# array([       nan,        nan,        nan, ..., 0.48197291, 0.48148727,
#        0.48167954])
